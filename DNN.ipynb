# %%
import tensorflow.compat.v1 as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np

# %%
np.random.seed(2018)
train_data, test_data = np.random.random((1000, 3)), np.random.random((500, 3))
labels = np.random.randint(2,size=(1000,1))

# %%
model=Sequential()
model.add(Dense(5,input_dim=3,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.fit(train_data,labels,epochs=10,batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7002 - accuracy: 0.5090
# Epoch 2/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6971 - accuracy: 0.5070
# Epoch 3/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6955 - accuracy: 0.4920
# Epoch 4/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6947 - accuracy: 0.5000
# Epoch 5/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6941 - accuracy: 0.5050
# Epoch 6/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6939 - accuracy: 0.5110
# Epoch 7/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6937 - accuracy: 0.4910
# Epoch 8/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6937 - accuracy: 0.4900
# Epoch 9/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6937 - accuracy: 0.5000
# Epoch 10/10
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6936 - accuracy: 0.5000

# %%
predictions = model.predict(test_data)

# %%
predictions
# Out:
# array([[0.51071984],
#        [0.47656032],
#        [0.44128275],
#        [0.51071984],
#        [0.5022486 ],
#        [0.51071984],
#        [0.48342994],
#        [0.47798797],
#        [0.50961185],
#        [0.51071984],
#        [0.51071984],
#        [0.5004763 ],
#        [0.5019744 ],
#        [0.49854296],
#        [0.47535837],
#        [0.50178415],
#        [0.5012965 ],
#        [0.5091311 ],
#        [0.48515797],
#        [0.49445516],
#        [0.45421326],
#        [0.5077094 ],
#        [0.4897707 ],
#        [0.50592065],
#        [0.49301788],
#        [0.51071984],
#        [0.50520605],
#        [0.51071984],
#        [0.50283504],
#        [0.49663982],
#        [0.51071984],
#        [0.50747854],
#        [0.50905466],
#        [0.5044094 ],
#        [0.5050288 ],
#        [0.48210505],
#        [0.5013856 ],
#        [0.5018861 ],
#        [0.49555025],
#        [0.4798263 ],
#        [0.49138644],
#        [0.49592406],
#        [0.4918319 ],
#        [0.49844658],
#        [0.5010054 ],
#        [0.4998473 ],
#        [0.4497863 ],
#        [0.4538104 ],
#        [0.51071984],
#        [0.50645864],
#        [0.49975795],
#        [0.5093296 ],
#        [0.50963813],
#        [0.51071984],
#        [0.50820404],
#        [0.49423757],
#        [0.45626935],
#        [0.4772998 ],
#        [0.48642656],
#        [0.51071984],
#        [0.5050695 ],
#        [0.500321  ],
#        [0.50503004],
#        [0.48962542],
#        [0.4750699 ],
#        [0.51071984],
#        [0.45523044],
#        [0.5039118 ],
#        [0.4842276 ],
#        [0.51071984],
#        [0.5104117 ],
#        [0.51071984],
#        [0.44136003],
#        [0.5060325 ],
#        [0.50181097],
#        [0.49935547],
#        [0.49727878],
#        [0.49826497],
#        [0.46715477],
#        [0.46290714],
#        [0.51071984],
#        [0.47610685],
#        [0.49827093],
#        [0.49834388],
#        [0.51071984],
#        [0.4706053 ],
#        [0.49223232],
#        [0.4786623 ],
#        [0.51071984],
#        [0.51071984],
#        [0.49028048],
#        [0.48515475],
#        [0.4556531 ],
#        [0.5028019 ],
#        [0.49970108],
#        [0.49188793],
#        [0.45542955],
#        [0.51071984],
#        [0.4982107 ],
#        [0.490854  ],
#        [0.51071984],
#        [0.45243675],
#        [0.50109535],
#        [0.50318736],
#        [0.5049223 ],
#        [0.51071984],
#        [0.4806075 ],
#        [0.50316364],
#        [0.47240564],
#        [0.49934694],
#        [0.51071984],
#        [0.51071984],
#        [0.51071984],
#        [0.44160888],
#        [0.51071984],
#        [0.49950224],
#        [0.48957735],
#        [0.4954368 ],
#        [0.51071984],
#        [0.49476156],
#        [0.48937598],
#        [0.51071984],
#        [0.49703324],
#        [0.5098581 ],
#        [0.49901238],
#        [0.46410245],
#        [0.49345428],
#        [0.5094047 ],
#        [0.47811458],
#        [0.50025874],
#        [0.51071984],
#        [0.47952977],
#        [0.5080126 ],
#        [0.4971801 ],
#        [0.49179637],
#        [0.5025051 ],
#        [0.51071984],
#        [0.51071984],
#        [0.49558827],
#        [0.47976983],
#        [0.50586   ],
#        [0.5041502 ],
#        [0.51071984],
#        [0.51071984],
#        [0.501875  ],
#        [0.47343373],
#        [0.48183402],
#        [0.5092701 ],
#        [0.5095302 ],
#        [0.50966257],
#        [0.51071984],
#        [0.49090713],
#        [0.51071984],
#        [0.50928265],
#        [0.50257176],
#        [0.51071984],
#        [0.507725  ],
#        [0.5063065 ],
#        [0.5076376 ],
#        [0.51071984],
#        [0.51071984],
#        [0.5061102 ],
#        [0.51071984],
#        [0.49235564],
#        [0.49974212],
#        [0.50472146],
#        [0.48951074],
#        [0.507132  ],
#        [0.51071984],
#        [0.5019098 ],
#        [0.5099488 ],
#        [0.5047807 ],
#        [0.4951097 ],
#        [0.5017358 ],
#        [0.48804906],
#        [0.47512743],
#        [0.50575817],
#        [0.50299144],
#        [0.5058453 ],
#        [0.51071984],
#        [0.49974078],
#        [0.48061004],
#        [0.51071984],
#        [0.4720123 ],
#        [0.49441776],
#        [0.49569997],
#        [0.51071984],
#        [0.50634307],
#        [0.5071348 ],
#        [0.49204537],
#        [0.48689774],
#        [0.50460917],
#        [0.51071984],
#        [0.50186914],
#        [0.46686712],
#        [0.51071984],
#        [0.47640443],
#        [0.45190465],
#        [0.49525276],
#        [0.51071984],
#        [0.51071984],
#        [0.48923448],
#        [0.49583578],
#        [0.49513897],
#        [0.44759652],
#        [0.4900038 ],
#        [0.5037075 ],
#        [0.50687414],
#        [0.5077126 ],
#        [0.5020134 ],
#        [0.49626672],
#        [0.51071984],
#        [0.46008557],
#        [0.4793443 ],
#        [0.47472   ],
#        [0.5052595 ],
#        [0.5007972 ],
#        [0.487214  ],
#        [0.51071984],
#        [0.4938022 ],
#        [0.48273847],
#        [0.51071984],
#        [0.5072732 ],
#        [0.49950317],
#        [0.49294725],
#        [0.49768755],
#        [0.51071984],
#        [0.51071984],
#        [0.47676948],
#        [0.49761018],
#        [0.50343835],
#        [0.4983011 ],
#        [0.49323496],
#        [0.51010954],
#        [0.4828345 ],
#        [0.49331412],
#        [0.49561265],
#        [0.51071984],
#        [0.49460587],
#        [0.51071984],
#        [0.50986755],
#        [0.5041937 ],
#        [0.51071984],
#        [0.5103431 ],
#        [0.49180037],
#        [0.51071984],
#        [0.5074983 ],
#        [0.49611425],
#        [0.4994681 ],
#        [0.48905107],
#        [0.49905506],
#        [0.50524515],
#        [0.51071984],
#        [0.5099813 ],
#        [0.5061607 ],
#        [0.49779087],
#        [0.49182996],
#        [0.5024707 ],
#        [0.47908166],
#        [0.5059495 ],
#        [0.50700974],
#        [0.50496083],
#        [0.501727  ],
#        [0.5025448 ],
#        [0.49436444],
#        [0.46576828],
#        [0.5051709 ],
#        [0.5007101 ],
#        [0.48578385],
#        [0.51071984],
#        [0.47983322],
#        [0.51071984],
#        [0.48089004],
#        [0.51071984],
#        [0.51028204],
#        [0.48949766],
#        [0.5015492 ],
#        [0.45639825],
#        [0.46759006],
#        [0.4979924 ],
#        [0.49533162],
#        [0.4933477 ],
#        [0.5014652 ],
#        [0.5089934 ],
#        [0.5003806 ],
#        [0.5078254 ],
#        [0.5097152 ],
#        [0.4971546 ],
#        [0.5017935 ],
#        [0.50417864],
#        [0.51071984],
#        [0.50541705],
#        [0.5033173 ],
#        [0.49395815],
#        [0.4831989 ],
#        [0.5082839 ],
#        [0.468715  ],
#        [0.49833483],
#        [0.47171915],
#        [0.5067845 ],
#        [0.49257883],
#        [0.51071984],
#        [0.51071984],
#        [0.4958635 ],
#        [0.51071984],
#        [0.5076763 ],
#        [0.49897313],
#        [0.5104426 ],
#        [0.49440867],
#        [0.49842057],
#        [0.50206155],
#        [0.49369928],
#        [0.50086766],
#        [0.47892502],
#        [0.49984497],
#        [0.49476027],
#        [0.5067988 ],
#        [0.49966848],
#        [0.5006284 ],
#        [0.5103233 ],
#        [0.5036825 ],
#        [0.4988638 ],
#        [0.51066613],
#        [0.4773836 ],
#        [0.5017848 ],
#        [0.49137872],
#        [0.47472656],
#        [0.5038899 ],
#        [0.49493903],
#        [0.4938646 ],
#        [0.47815374],
#        [0.4839246 ],
#        [0.5046002 ],
#        [0.5018827 ],
#        [0.4564733 ],
#        [0.49997962],
#        [0.5006051 ],
#        [0.4824197 ],
#        [0.4971309 ],
#        [0.49748147],
#        [0.4893844 ],
#        [0.4881133 ],
#        [0.5004389 ],
#        [0.47421443],
#        [0.4936574 ],
#        [0.51034546],
#        [0.50401044],
#        [0.47937876],
#        [0.50670975],
#        [0.51071984],
#        [0.4574235 ],
#        [0.50266767],
#        [0.4852745 ],
#        [0.4819294 ],
#        [0.5023392 ],
#        [0.4923522 ],
#        [0.50473076],
#        [0.51071984],
#        [0.51071984],
#        [0.47784528],
#        [0.51071984],
#        [0.50628287],
#        [0.508582  ],
#        [0.51071984],
#        [0.4666257 ],
#        [0.492845  ],
#        [0.5025042 ],
#        [0.5091639 ],
#        [0.5049515 ],
#        [0.47709888],
#        [0.5001776 ],
#        [0.49961507],
#        [0.51071984],
#        [0.4821446 ],
#        [0.49849743],
#        [0.48449066],
#        [0.49527606],
#        [0.5109984 ],
#        [0.51071984],
#        [0.4979727 ],
#        [0.44731316],
#        [0.5045617 ],
#        [0.5100884 ],
#        [0.45220786],
#        [0.5004671 ],
#        [0.4932071 ],
#        [0.4951787 ],
#        [0.49625874],
#        [0.47868767],
#        [0.48677766],
#        [0.48802108],
#        [0.49924627],
#        [0.44336024],
#        [0.50138855],
#        [0.4916353 ],
#        [0.47918713],
#        [0.48164555],
#        [0.5059093 ],
#        [0.47843322],
#        [0.4902914 ],
#        [0.498953  ],
#        [0.49028295],
#        [0.49117082],
#        [0.50940126],
#        [0.50116813],
#        [0.49943945],
#        [0.51096386],
#        [0.50891703],
#        [0.4914048 ],
#        [0.51071984],
#        [0.51071984],
#        [0.51071984],
#        [0.51071984],
#        [0.4838728 ],
#        [0.50772244],
#        [0.50640917],
#        [0.51071984],
#        [0.51071984],
#        [0.5019389 ],
#        [0.47314578],
#        [0.49781823],
#        [0.51071984],
#        [0.48590595],
#        [0.51071984],
#        [0.46724856],
#        [0.46534577],
#        [0.5090034 ],
#        [0.5028842 ],
#        [0.5006592 ],
#        [0.4532764 ],
#        [0.49401122],
#        [0.49241772],
#        [0.50260437],
#        [0.4984468 ],
#        [0.49106175],
#        [0.4887731 ],
#        [0.48677418],
#        [0.47554678],
#        [0.4960289 ],
#        [0.49374884],
#        [0.47353005],
#        [0.49899274],
#        [0.4916749 ],
#        [0.4813623 ],
#        [0.45799085],
#        [0.49879608],
#        [0.46910185],
#        [0.51071984],
#        [0.51071984],
#        [0.51071984],
#        [0.484677  ],
#        [0.5090883 ],
#        [0.51071984],
#        [0.4467336 ],
#        [0.49960735],
#        [0.4988941 ],
#        [0.45295775],
#        [0.43081653],
#        [0.51071984],
#        [0.45861182],
#        [0.43667892],
#        [0.48050833],
#        [0.4894089 ],
#        [0.48610142],
#        [0.49025366],
#        [0.49685946],
#        [0.50551987],
#        [0.51071984],
#        [0.5068408 ],
#        [0.47216275],
#        [0.4940866 ],
#        [0.4659161 ],
#        [0.5054113 ],
#        [0.51071984],
#        [0.51071984],
#        [0.5076369 ],
#        [0.50403017],
#        [0.50789785],
#        [0.49974602],
#        [0.49627137],
#        [0.48061106],
#        [0.47220328],
#        [0.4947212 ],
#        [0.51071984],
#        [0.5097464 ],
#        [0.49995342],
#        [0.49023706],
#        [0.49559715],
#        [0.5020256 ],
#        [0.5019882 ],
#        [0.48869005],
#        [0.5054709 ],
#        [0.51071984],
#        [0.51071984],
#        [0.51071984],
#        [0.47082904],
#        [0.5092597 ],
#        [0.51071984],
#        [0.51177305],
#        [0.4618874 ]], dtype=float32)

# %%
sess.run(x.initializer)
sess.run(y.initializer)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 sess.run(x.initializer)
#       2 sess.run(y.initializer)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py:957, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     954 run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     956 try:
# --> 957   result = self._run(None, fetches, feed_dict, options_ptr,
#     958                      run_metadata_ptr)
#     959   if run_metadata:
#     960     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py:1106, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    1104   raise RuntimeError('Attempted to use a closed Session.')
#    1105 if self.graph.version == 0:
# -> 1106   raise RuntimeError('The Session graph is empty.  Add operations to the '
#    1107                      'graph before calling run().')
#    1109 # Create request.
#    1110 feed_dict_tensor = {}
#
# RuntimeError: The Session graph is empty.  Add operations to the graph before calling run().

# %%
result = sess.run(f)
